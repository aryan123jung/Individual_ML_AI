# %%
import pandas as pd
import os

pd.set_option("display.max_columns", 30)
pd.set_option("display.width", 200)

BASE = "/Users/aryanjungchhetri/Developers/6th sem/individual"

# ─── LOAD ─────────────────────────────────────────────────────────────────────
batting_df = pd.read_csv(f"{BASE}/data/processed/ipl_batting_raw.csv")
bowling_df = pd.read_csv(f"{BASE}/data/processed/ipl_bowling_raw.csv")

print("✅ Reloaded")
print(f"Batting : {batting_df.shape}")
print(f"Bowling : {bowling_df.shape}")

# ─── NULLS ────────────────────────────────────────────────────────────────────
print("\n=== BATTING NULLS ===")
print(batting_df.isnull().sum().to_string())

print("\n=== BOWLING NULLS ===")
print(bowling_df.isnull().sum().to_string())

# ─── SEASONS ──────────────────────────────────────────────────────────────────
print("\n=== MATCHES PER SEASON ===")
print(batting_df.groupby("season")["match_file"].nunique().to_string())

# ─── TEAMS ────────────────────────────────────────────────────────────────────
print("\n=== IPL TEAMS ===")
print(batting_df["team"].value_counts().to_string())

# ─── TOP SCORERS ──────────────────────────────────────────────────────────────
print("\n=== TOP 10 RUN SCORERS ===")
print(batting_df.groupby("player")["runs"].sum().sort_values(ascending=False).head(10).to_string())

# ─── TOP WICKET TAKERS ────────────────────────────────────────────────────────
print("\n=== TOP 10 WICKET TAKERS ===")
print(bowling_df.groupby("player")["wickets"].sum().sort_values(ascending=False).head(10).to_string())

# ─── ZERO BALLS FACED ─────────────────────────────────────────────────────────
print("\n=== BATTERS WITH 0 BALLS FACED ===")
zero_balls = batting_df[batting_df["balls_faced"] == 0]
print(f"Count : {len(zero_balls)}")

# ─── BASIC STATS ──────────────────────────────────────────────────────────────
print("\n=== BATTING BASIC STATS ===")
print(batting_df[["runs", "balls_faced", "fours", "sixes", "dismissed"]].describe().to_string())

print("\n=== BOWLING BASIC STATS ===")
print(bowling_df[["runs_conceded", "balls_bowled", "wickets", "wides", "noballs"]].describe().to_string())

# ─── UNIQUE COUNTS ────────────────────────────────────────────────────────────
print("\n=== UNIQUE COUNTS ===")
print(f"Unique batters  : {batting_df['player'].nunique()}")
print(f"Unique bowlers  : {bowling_df['player'].nunique()}")
print(f"Unique teams    : {batting_df['team'].nunique()}")
print(f"Unique venues   : {batting_df['venue'].nunique()}")
print(f"Unique seasons  : {batting_df['season'].nunique()}")
# Out:
# ✅ Reloaded
# Batting : (18057, 23)
# Bowling : (14118, 22)
#
# === BATTING NULLS ===
# player          0
# match_file      0
# tournament      0
# match_number    0
# date            0
# season          0
# venue           0
# city            0
# team            0
# opponent        0
# winner          0
# runs            0
# balls_faced     0
# fours           0
# sixes           0
# dismissed       0
# pp_runs         0
# pp_balls        0
# mid_runs        0
# mid_balls       0
# death_runs      0
# death_balls     0
# dot_balls       0
#
# === BOWLING NULLS ===
# player           0
# match_file       0
# tournament       0
# match_number     0
# date             0
# season           0
# venue            0
# city             0
# team             0
# winner           0
# runs_conceded    0
# balls_bowled     0
# wickets          0
# wides            0
# noballs          0
# dot_balls        0
# pp_runs          0
# pp_balls         0
# mid_runs         0
# mid_balls        0
# death_runs       0
# death_balls      0
#
# === MATCHES PER SEASON ===
# season
# 2007/08    58
# 2009       57
# 2009/10    60
# 2011       73
# 2012       74
# 2013       76
# 2014       60
# 2015       59
# 2016       60
# 2017       59
# 2018       60
# 2019       60
# 2020/21    60
# 2021       60
# 2022       74
# 2023       74
# 2024       71
# 2025       74
# 2026       24
#
# === IPL TEAMS ===
# team
# Mumbai Indians                 2158
# Kolkata Knight Riders          2037
# Rajasthan Royals               1824
# Chennai Super Kings            1811
# Royal Challengers Bangalore    1788
# Sunrisers Hyderabad            1512
# Kings XI Punjab                1475
# Delhi Daredevils               1219
# Delhi Capitals                  868
# Punjab Kings                    622
# Deccan Chargers                 600
# Lucknow Super Giants            502
# Gujarat Titans                  454
# Pune Warriors                   372
# Royal Challengers Bengaluru     262
# Gujarat Lions                   238
# Rising Pune Supergiant          114
# Kochi Tuskers Kerala            110
# Rising Pune Supergiants          91
#
# === TOP 10 RUN SCORERS ===
# player
# V Kohli           8899
# RG Sharma         7185
# S Dhawan          6769
# DA Warner         6567
# SK Raina          5536
# MS Dhoni          5439
# KL Rahul          5346
# AM Rahane         5184
# AB de Villiers    5181
# CH Gayle          4997
#
# === TOP 10 WICKET TAKERS ===
# player
# YS Chahal     224
# B Kumar       205
# SP Narine     195
# PP Chawla     192
# R Ashwin      187
# JJ Bumrah     186
# DJ Bravo      183
# A Mishra      174
# RA Jadeja     173
# SL Malinga    170
#
# === BATTERS WITH 0 BALLS FACED ===
# Count : 59
#
# === BATTING BASIC STATS ===
#                runs   balls_faced         fours         sixes     dismissed
# count  18057.000000  18057.000000  18057.000000  18057.000000  18057.000000
# mean      20.131306     15.193000      1.820125      0.818353      0.781193
# std       21.522926     13.438558      2.319106      1.398584      0.416784
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        4.000000      5.000000      0.000000      0.000000      1.000000
# 50%       13.000000     11.000000      1.000000      0.000000      1.000000
# 75%       30.000000     22.000000      3.000000      1.000000      1.000000
# max      175.000000     73.000000     19.000000     17.000000      2.000000
#
# === BOWLING BASIC STATS ===
#        runs_conceded  balls_bowled       wickets         wides       noballs
# count   14118.000000  14118.000000  14118.000000  14118.000000  14118.000000
# mean       27.117864     19.348137      0.914860      0.661425      0.083794
# std        11.203109      6.143372      1.000307      0.956947      0.318257
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        19.000000     18.000000      0.000000      0.000000      0.000000
# 50%        27.000000     24.000000      1.000000      0.000000      0.000000
# 75%        35.000000     24.000000      1.000000      1.000000      0.000000
# max        80.000000     30.000000      6.000000      8.000000      4.000000
#
# === UNIQUE COUNTS ===
# Unique batters  : 720
# Unique bowlers  : 564
# Unique teams    : 19
# Unique venues   : 59
# Unique seasons  : 19
